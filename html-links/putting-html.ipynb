# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Request URL
page = requests.get("https://www.pgatour.com/stats/categories.RPUT_INQ.html")
soup = BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
# Out:
# gory-index="5">
#              <a href="/stats/stat.396.html">
#               Putts per Round - Round 4
#              </a>
#             </li>
#             <li class="" data-category-index="5">
#              <a href="/stats/stat.397.html">
#               Putts per Round - Round 5
#              </a>
#             </li>
#             <li class="" data-category-index="5">
#              <a href="/stats/stat.398.html">
#               1-Putts per Round
#              </a>
#             </li>
#             <li class="" data-category-index="5">
#              <a href="/stats/stat.399.html">
#               2-Putts per Round
#              </a>
#             </li>
#             <li class="" data-category-index="5">
#              <a href="/stats/stat.400.html">
#               3-Putts per Round
#              </a>
#             </li>
#             <li class="" data-category-index="5">
#              <a href="/stats/stat.401.html">
#               3+ Putts per Round
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="module-statistics-off-the-tee-table clear">
#           <div class="header">
#            <h3>
#             Putting Averages
#            </h3>
#           </div>
#           <div class="table-content clearfix">
#            <ul>
#             <li class="" data-category-index="6">
#              <a href="/stats/stat.02428.html">
#               Total Putting
#              </a>
#             </li>
#             <li class="" data-category-index="6">
#              <a href="/stats/stat.02439.html">
#               Bonus Putting
#              </a>
#             </li>
#             <li class="" data-category-index="6">
#              <a href="/stats/stat.104.html">
#               Putting Average
#              </a>
#             </li>
#             <li class="" data-category-index="6">
#              <a href="/stats/stat.402.html">
#               Overall Putting Average
#              </a>
#             </li>
#             <li class="" data-category-index="6">
#              <a href="/stats/stat.115.html">
#               Birdie or Better Conversion Percentage
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="module-statistics-off-the-tee-table">
#           <div class="header">
#            <h3>
#             Avg. Putting Dist.
#            </h3>
#           </div>
#           <div class="table-content clearfix">
#            <ul>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.409.html">
#               Average Putting Distance - All 1 putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.410.html">
#               Average Putting Distance - All 2 putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.411.html">
#               Average Putting Distance - All 3 putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.412.html">
#               Average Putting Distance - All 3+ putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.389.html">
#               Average Putting Distance - GIR 1 Putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.390.html">
#               Average Putting Distance - GIR 2 Putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.391.html">
#               Average Putting Distance - GIR 3 Putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.392.html">
#               Average Putting Distance - GIR 3+ Putts
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.438.html">
#               Average Distance of Putts made
#              </a>
#             </li>
#             <li class="" data-category-index="7">
#              <a href="/stats/stat.02440.html">
#               Average Distance of Birdie putts made
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="7">
#              <a href="/stats/stat.02442.html">
#               Average Distance of Eagle putts made
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="7">
#              <a href="/stats/stat.135.html">
#               Putts made Distance
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="7">
#              <a href="/stats/stat.349.html">
#               Approach Putt Performance
#              </a>
#             </li>
#            </ul>
#           </div>
#           <a class="show-more visible-small" data-category-index="7" href="javascript:void(0)">
#            show more
#           </a>
#          </div>
#         </div>
#         <div class="stats-sponsor-logo bottom">
#          <img alt="" src="/content/dam/pgatour/logos/CDW/SHOTLINT.png"/>
#         </div>
#        </section>
#        <script type="text/javascript">
#         new pgatour.stats.CategoriesList('section.module-statistics-off-the-tee');
#        </script>
#       </div>
#      </div>
#      <div class="mainParsys2 parsys">
#      </div>
#     </div>
#     <div class="parsys iparsys dontMissThisIParsys">
#      <div class="section">
#       <div class="new">
#       </div>
#      </div>
#      <div class="iparys_inherited">
#       <div class="parsys iparsys dontMissThisIParsys">
#        <div class="parbase dontMissThis section">
#         <section class="footer-dont-miss-this hidden-small" data-react-module-name="FooterDontMissThis" style="visibility:hidden">
#          <p class="footer-links-head">
#           Don't Miss This
#          </p>
#          <div class="links-img clearfix">
#           <div class="item">
#            <a href="https://www.pgatour.com/fantasy.html" onclick="return pgatour.linkTarget.open(this, -1, -1)">
#             <img data-src="pgatour/editorial/Banners/Homepage/Don't%20Miss%20This/DMT_Fantasy-Generic-304x186.jpg" src="/etc/designs/pgatour-libs/img/1x1.png"/>
#            </a>
#           </div>
#           <div class="item">
#            <a href="https://www.pgatoursuperstore.com/home/?utm_source=PGATOUR.com&amp;utm_medium=Banner&amp;utm_content=PGA_TOUR&amp;utm_campaign=PGA_TOUR&amp;utm_kxconfid=tdkdhznwc" onclick="return pgatour.linkTarget.open(this, -1, -1)">
#             <img data-src="pgatour/dont-miss-this/2019_PGATSS_US_PGATSS-TOUR-SET1-304x186.jpg" src="/etc/designs/pgatour-libs/img/1x1.png"/>
#            </a>
#           </div>
#           <div class="item">
#            <a href="https://www.pgatour.com/long-form.html?utm_medium=house-ad&amp;utm_source=dmt&amp;utm_campaign=GenericLF&amp;pid=GenericLF" onclick="return pgatour.linkTarget.open(this, -1, -1)">
#             <img data-src="pgatour/dont-miss-this/Longform-DontMissThis_304x186.jpg" src="/etc/designs/pgatour-libs/img/1x1.png"/>
#            </a>
#           </div>
#           <div class="item">
#            <a href="https://www.theplayers.com/" onclick="return pgatour.linkTarget.open(this, -1, -1)">
#             <img data-src="pgatour/editorial/Banners/Homepage/Don't%20Miss%20This/DontMissThisModule-TPCRenovation1_304x186.png" src="/etc/designs/pgatour-libs/img/1x1.png"/>
#            </a>
#           </div>
#          </div>
#         </section>
#         <script>
#          pgatour.ReactModulesUtils.render(document.querySelector('[data-react-module-name=FooterDontMissThis]'), function () {
#         var dontMissThis = new pgatour.FooterDontMissThis(jQuery('.footer-dont-miss-this'));
#     });
#         </script>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- container -->
#   </div>
#   <!-- wrap -->
#   <!-- footer -->
#   <div class="footerIParsys parsys iparsys">
#    <div class="section">
#     <div class="new">
#     </div>
#    </div>
#    <div class="iparys_inherited">
#     <div class="footerIParsys parsys iparsys">
#      <div class="section footerNavigation">
#       <div class="footer" data-react-module-name="FooterNavigation" style="visibility:hidden">
#        <div class="footer-lists">
#         <div class="footer-main hidden-small">
#          <div class="container">
#           <ul class="main-list">
#            <li class="item">
#             <a href="/company/aboutus.html" target="_self">
#              <span class="link-image">
#               <img src="/content/dam/pgatour/footer/icons/corporate.png"/>
#              </span>
#              <span class="link-text">
#               About the PGA TOUR
#              </span>
#             </a>
#            </li>
#            <li class="item">
#             <a class="login-button" data-action="login" href="#">
#              <span class="link-image">
#               <img src="/content/dam/pgatour/footer/icons/login.png"/>
#              </span>
#              <span class="link-text login">
#               Log In / Register
#              </span>
#              <span class="link-text profile">
#               Manage Profile
#              </span>
#             </a>
#            </li>
#            <li class="item">
#             <a href="/company/omps.html" target="_self">
#              <span class="link-image">
#               <img src="/content/dam/pgatour/footer/icons/marketing-partners.png"/>
#              </span>
#              <span class="link-text">
#               Marketing Partners
#              </span>
#             </a>
#            </li>
#            <li class="item">
#             <a href="/company/partner-sites.html" target="_self">
#              <span class="link-image">
#               <img src="/content/dam/pgatour/footer/icons/partners.png"/>
#              </span>
#              <span class="link-text">
#               Affiliate &amp; International Partners
#              </span>
#             </a>
#            </li>
#            <li class="item">
#             <a href="https://tpc.com/?utm_source=pgatour.com&amp;utm_medium=digital&amp;utm_campaign=footer-link" target="_self">
#              <span class="link-image">
#               <img src="/content/dam/pgatour/footer/icons/TPC_wire_42x55.png"/>
#              </span>
#              <span class="link-text">
#               TPC Network
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="footer-sub">
#          <div class="container">
#           <ul class="sub-list">
#            <li class="item visible-small">
#             <a href="/company/aboutus.html" target="_self">
#              About the PGA TOUR
#             </a>
#            </li>
#            <li class="item visible-small">
#             <a class="login-button" data-action="login" href="#">
#              <span class="link-text login">
#               Log In / Register
#              </span>
#              <span class="link-text profile">
#               Manage Profile
#              </span>
#             </a>
#            </li>
#            <li class="item visible-small">
#             <a href="/company/omps.html" target="_self">
#              Marketing Partners
#             </a>
#            </li>
#            <li class="item visible-small">
#             <a href="/company/partner-sites.html" target="_self">
#              Affiliate &amp; International Partners
#             </a>
#            </li>
#            <li class="item visible-small">
#             <a href="https://tpc.com/?utm_source=pgatour.com&amp;utm_medium=digital&amp;utm_campaign=footer-link" target="_self">
#              TPC Network
#             </a>
#            </li>
#            <li class="item">
#             <a href="/company/tos.html" target="_self">
#              Terms of Service
#             </a>
#            </li>
#            <li class="item">
#             <a href="/company/privacy-policy.html" target="_self">
#              Privacy Policy
#             </a>
#            </li>
#            <li class="item truste-link">
#             <div id="teconsent">
#             </div>
#            </li>
#            <li class="item">
#             <a href="/tournaments/tickets.html" target="_self">
#              Tournament Tickets
#             </a>
#            </li>
#            <li class="item">
#             <a href="https://pgatourcareers.silkroad.com" target="_blank">
#              Careers
#             </a>
#            </li>
#            <li class="item">
#             <a href="/company/contact-us.html" target="_self">
#              Contact Us
#             </a>
#            </li>
#            <li class="item">
#             <a href="/advertise.html" target="_self">
#              Advertise
#             </a>
#            </li>
#            <li class="item">
#             <a href="/company/sitemap.html" target="_self">
#              Sitemap
#             </a>
#            </li>
#            <li class="item">
#             <a href="http://pgatourmedia.com" target="_self">
#              Media
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#       <script>
#        pgatour.ReactModulesUtils.render(document.querySelector('[data-react-module-name=FooterNavigation]'), function () {
#         var footer = new pgatour.Footer(jQuery('.footer-lists'));
#     });
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="subFooterIParsys parsys iparsys">
#    <div class="section">
#     <div class="new">
#     </div>
#    </div>
#    <div class="iparys_inherited">
#     <div class="subFooterIParsys parsys iparsys">
#      <div class="footerCopyright section">
#       <div class="footer-copyright" data-react-module-name="FooterCopyright" style="visibility:hidden">
#        <div class="footer-copyright">
#         <div class="container">
#          <p>
#           <p>
#            <a href="/company/privacy-policy.html#topAdIParsys1_iparsys_fake_par">
#            </a>
#            <a href="https://www.pgatour.com/company/privacy-policy.html#DoNot">
#             Do Not Sell My Personal Information
#            </a>
#           </p>
#           <p>
#            © 2020 PGA TOUR, Inc | All Rights Reserved.
#            <br/>
#            PGA TOUR, PGA TOUR Champions, and the Swinging Golfer design are registered trademarks.
#            <br/>
#            The Korn Ferry trademark is also a registered trademark, and is used in the Korn Ferry Tour logo with permission.
#            <br/>
#           </p>
#          </p>
#         </div>
#        </div>
#       </div>
#       <script>
#        pgatour.ReactModulesUtils.render(document.querySelector('[data-react-module-name=FooterCopyright]'), function () {
#
#     });
#       </script>
#      </div>
#      <div class="footerlConnectWith section">
#      </div>
#      <div class="footerConnectWith2 section">
#       <div class="connect-with footer-social" data-react-module-name="FooterConnectWith" style="visibility:hidden">
#        <div class="container">
#         <div class="title">
#          <div style="text-align: center;">
#           CONNECT WITH
#           <b>
#            THE PGA TOUR
#           </b>
#           ON
#          </div>
#         </div>
#         <div class="clearfix social-items">
#          <a class="social-logo" href="https://www.facebook.com/PGATour" target="_self">
#           <img src="https://pga-tour-res.cloudinary.com/image/upload/q_auto/v1/pgatour/image/footer/social-facebook.png"/>
#          </a>
#          <a class="social-logo" href="https://twitter.com/pgatour" target="_self">
#           <img src="https://pga-tour-res.cloudinary.com/image/upload/q_auto/v1/pgatour/image/footer/social-twitter.png"/>
#          </a>
#          <a class="social-logo" href="https://www.instagram.com/pgatour" target="_self">
#           <img src="https://pga-tour-res.cloudinary.com/image/upload/q_auto/v1/pgatour/footer/icons/social-instagram.png"/>
#          </a>
#          <a class="social-logo" href="https://www.youtube.com/pgatour" target="_self">
#           <img src="https://pga-tour-res.cloudinary.com/image/upload/q_auto/v1/pgatour/footer/icons/social-youtube.png"/>
#          </a>
#          <a class="social-logo" href="/mobile.html" target="_self">
#           <img src="https://pga-tour-res.cloudinary.com/image/upload/q_auto/v1/pgatour/image/footer/social%20icons_m.png"/>
#          </a>
#         </div>
#        </div>
#       </div>
#       <script>
#        pgatour.ReactModulesUtils.render(document.querySelector('[data-react-module-name=FooterConnectWith]'), function() {
#         var footerSocial = new pgatour.BaseCloudinaryModule(jQuery('.footer-social'));
#     });
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- /footer -->
#   <div class="adOverlayIParsys parsys iparsys">
#    <div class="section">
#     <div class="new">
#     </div>
#    </div>
#    <div class="iparys_inherited">
#     <div class="adOverlayIParsys parsys iparsys">
#      <div class="section adOverlay">
#       <div class="ad-overlay hidden">
#        <div class="ad-new">
#         <script type="text/javascript">
#          new pgatour.Ad({"justInTime":false,"options":{"pos":"interstitial"},"refreshOnResize":false,"companionAd":false,"justOnScroll":false,"suspended":false,"trackBrowserActivity":false,"size":{"large":"out-of-page","medium":"out-of-page","small":"out-of-page"}});
#         </script>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- Begin comScore Tag -->
#   <script type="text/javascript">
#    var _comscore = _comscore || [];
#     _comscore.push({ c1:"2", c2:"15095216" });
#     (function () {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#         s.async = true;
#         s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
#   </script>
#   <noscript>
#    <img alt="Image" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=15095216&amp;cv=2.0&amp;cj=1">
#    </img>
#   </noscript>
#   <!-- End comScore Tag -->
#   <!-- SiteCatalyst code version: H.25.2.
# Copyright 1996-2012 Adobe, Inc. All Rights Reserved
# More info available at http://www.omniture.com -->
#   <script type="text/javascript">
#    /* You may give each page an identifying name, server, and channel on
#  the next lines. */
#     pgatour.Omniture.defineOmnitureVars();
#   </script>
#   <!-- Adobe DTM -->
#   <script type="text/javascript">
#    _satellite.pageBottom();
#   </script>
#   <script>
#    window.__gigyaConf = {
#             cid: window.location.hostname.replace('www.', '').toUpperCase()
#         }
#   </script>
#   <script src="https://cdns.gigya.com/JS/socialize.js?apikey=3_IscKmAoYcuwP8zpTnatC3hXBUm8rPuI-Hg_cZJ-jL-M7LgqCkxmwe-ps1Qy7PoWd" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    pgatour.GigyaSocialize.init({
#             liveFyreCookieName: 'lfauth',
#             liveFyreLoginUrl: 'https://livefyre.pgatour.com/livefyre.php',
#             getIpUrl: 'https://livefyre.pgatour.com/ip.php',
#             liveFyrePingUrl: 'https://livefyre.pgatour.com/livefyreping.php',
#             kruxBaseUrl: '//beacon.krxd.net/usermatch.gif?',
#             kruxPartnerId: 'gigya',
#             playersFeed: 'https://statdata.pgatour.com/players/player.json'
#         });
#   </script>
#   <script type="text/javascript">
#    (function() {
# /** CONFIGURATION START **/
# var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
# _sf_async_config.sections = "Stats"; // CHANGE THIS TO YOUR SECTION NAME(s)
# _sf_async_config.authors = "Administrator"; // CHANGE THIS TO YOUR AUTHOR NAME(s)
# /** CONFIGURATION END **/
#     function loadChartbeat() {
#         var e = document.createElement('script');
#         var n = document.getElementsByTagName('script')[0];
#         e.type = 'text/javascript';
#         e.async = true;
#         e.src = '//static.chartbeat.com/js/chartbeat.js';
#         n.parentNode.insertBefore(e, n);
#     }
#     loadChartbeat();
# })();
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","licenseKey":"0ee18552e2","agent":"","beacon":"bam.nr-data.net","applicationTime":559,"applicationID":"13137588","transactionName":"ZVRRbUBVWhUHBUVfDVwecExBQFsLSQdBRhEdQVRYRltBFEsVWEIHHUVWVEJYVRIDFR5ZDFdyXFVHWVo2BwFU","queueTime":0}
#   </script>
#  </body>
# </html>

# %%
index = [i for i in range(0, 8)]

# %%
htmlLink = soup.find_all("li", {"class":"", "data-category-index":index})
htmlLink
# Out:
# [<li class="" data-category-index="0">
#  <a href="/stats/stat.02564.html">SG: Putting</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.413.html">One-Putt Percentage</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.414.html">One-Putt Percentage - Round 1</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.415.html">One-Putt Percentage - Round 2</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.416.html">One-Putt Percentage - Round 3</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.417.html">One-Putt Percentage - Round 4</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.418.html">One-Putt Percentage - Round 5</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.420.html">Total 1 Putts - Inside 5'</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.421.html">Total 1 Putts - 5-10'</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.422.html">Total 1 Putts - 10-15'</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.423.html">Total 1 Putts - 15-20'</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.426.html">3-Putt Avoidance</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.427.html">3-Putt Avoidance - Round 1</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.428.html">3-Putt Avoidance - Round 2</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.429.html">3-Putt Avoidance - Round 3</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.430.html">3-Putt Avoidance - Round 4</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.440.html">3-Putt Avoidance - Round 5</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.068.html">3-Putt Avoidance - Inside 5'</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.069.html">3-Putt Avoidance - 5-10'</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.070.html">3-Putt Avoidance - 10-15'</a>
#  </li>,
#  <li class="" data-category-index="2">
#  <a href="/stats/stat.145.html">3-Putt Avoidance - 15-20'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.408.html">Putting from - &gt; 25'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.02429.html">Putting from - &gt; 20'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.02328.html">Putting from 15-25'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.407.html">Putting from - 20-25'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.406.html">Putting from - 15-20'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.02327.html">Putting from 5-15'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.405.html">Putting from - 10-15'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.484.html">Putting - Inside 10'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.404.html">Putting from 5-10'</a>
#  </li>,
#  <li class="" data-category-index="3">
#  <a href="/stats/stat.02427.html">Putting from 3-5'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.073.html">GIR Putting Avg - &gt; 35'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.072.html">GIR Putting Avg - 30-35'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.071.html">GIR Putting Avg - 25-30'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.388.html">GIR Putting - &gt; 25'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.387.html">GIR Putting - 20-25'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.386.html">GIR Putting - 15-20'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.385.html">GIR Putting - 10-15'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.384.html">GIR Putting - 5-10'</a>
#  </li>,
#  <li class="" data-category-index="4">
#  <a href="/stats/stat.383.html">GIR Putting - Inside 5'</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.119.html">Putts Per Round</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.393.html">Putts per Round - Round 1</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.394.html">Putts per Round - Round 2</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.395.html">Putts per Round - Round 3</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.396.html">Putts per Round - Round 4</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.397.html">Putts per Round - Round 5</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.398.html">1-Putts per Round</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.399.html">2-Putts per Round</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.400.html">3-Putts per Round</a>
#  </li>,
#  <li class="" data-category-index="5">
#  <a href="/stats/stat.401.html">3+ Putts per Round</a>
#  </li>,
#  <li class="" data-category-index="6">
#  <a href="/stats/stat.02428.html">Total Putting</a>
#  </li>,
#  <li class="" data-category-index="6">
#  <a href="/stats/stat.02439.html">Bonus Putting</a>
#  </li>,
#  <li class="" data-category-index="6">
#  <a href="/stats/stat.104.html">Putting Average</a>
#  </li>,
#  <li class="" data-category-index="6">
#  <a href="/stats/stat.402.html">Overall Putting Average</a>
#  </li>,
#  <li class="" data-category-index="6">
#  <a href="/stats/stat.115.html">Birdie or Better Conversion Percentage</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.409.html">Average Putting Distance - All 1 putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.410.html">Average Putting Distance - All 2 putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.411.html">Average Putting Distance - All 3 putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.412.html">Average Putting Distance - All 3+ putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.389.html">Average Putting Distance - GIR 1 Putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.390.html">Average Putting Distance - GIR 2 Putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.391.html">Average Putting Distance - GIR 3 Putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.392.html">Average Putting Distance - GIR 3+ Putts</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.438.html">Average Distance of Putts made</a>
#  </li>,
#  <li class="" data-category-index="7">
#  <a href="/stats/stat.02440.html">Average Distance of Birdie putts made</a>
#  </li>]
