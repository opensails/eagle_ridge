# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Request URL
page = requests.get("https://www.pgatour.com/stats/categories.RSCR_INQ.html")
soup = BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
# Out:
# rly Round 5 Scoring Average
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="11">
#              <a href="/stats/stat.284.html">
#               Tenth Tee Late Round 5 Scoring Average
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="11">
#              <a href="/stats/stat.306.html">
#               Tenth Tee Early Lowest Round
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="11">
#              <a href="/stats/stat.308.html">
#               Tenth Tee Late Lowest Round
#              </a>
#             </li>
#            </ul>
#           </div>
#           <a class="show-more visible-small" data-category-index="11" href="javascript:void(0)">
#            show more
#           </a>
#          </div>
#          <div class="module-statistics-off-the-tee-table clear">
#           <div class="header">
#            <h3>
# ...

# %%
index = [i for i in range(11, 13)]

# %%
htmlLink = soup.find_all("li", {"class":"", "data-category-index":index})
htmlLink
# Out:
# [<li class="" data-category-index="11">
#  <a href="/stats/stat.210.html">Tenth Tee Early Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.212.html">Tenth Tee Late Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.226.html">Tenth Tee Early Par 3 Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.228.html">Tenth Tee Late Par 3 Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.234.html">Tenth Tee Early Par 4 Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.236.html">Tenth Tee Late Par 4 Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.242.html">Tenth Tee Early Par 5 Scoring Average</a>
#  </li>,
#  <li class="" data-category-index="11">
#  <a href="/stats/stat.244.html">Tenth Tee Late Par 5 Scoring Average</a>
# ...
