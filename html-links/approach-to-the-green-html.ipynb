# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Request URL
page = requests.get("https://www.pgatour.com/stats/categories.RAPP_INQ.html")
soup = BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
# Out:
# ="/stats/stat.02387.html">
#               Approaches &gt; 200 yards-Rgh (RTP)
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="4">
#              <a href="/stats/stat.02388.html">
#               Approaches &lt; 100 yards-Rgh (RTP)
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="4">
#              <a href="/stats/stat.02389.html">
#               Approaches &gt; 100 yards-Rgh (RTP)
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="4">
#              <a href="/stats/stat.02390.html">
#               Approaches 200-225 yards-Rgh (RTP)
#              </a>
#             </li>
#             <li class="hidden-small" data-category-index="4">
#              <a href="/stats/stat.02391.html">
#               Approaches 225-250 yards-Rgh (RTP)
#              </a>
#             </li>
# ...

# %%
index = [i for i in range(0, 8)]

# %%
htmlLink = soup.find_all("li", {"class":"", "data-category-index":index})
htmlLink
# Out:
# [<li class="" data-category-index="0">
#  <a href="/stats/stat.02568.html">SG: Approach the Green</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.103.html">Greens in Regulation Percentage</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.02437.html">Greens or Fringe in Regulation</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.326.html">GIR Percentage - 200+ yards</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.327.html">GIR Percentage - 175-200 yards</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.328.html">GIR Percentage - 150-175 yards</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.329.html">GIR Percentage - 125-150 yards</a>
#  </li>,
#  <li class="" data-category-index="1">
#  <a href="/stats/stat.330.html">GIR Percentage - &lt; 125 yards</a>
#  </li>,
#  <li class="" data-category-index="1">
# ...

# %%
for a in soup.find_all('a', href=True):
    print ("Found the URL:", a['href'])
# Out:
# Found the URL: #
# Found the URL: http://windows.microsoft.com/en-us/internet-explorer/download-ie
# Found the URL: https://www.pgatour.com
# Found the URL: https://www.pgatour.com
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: /champions.html
# Found the URL: /korn-ferry-tour.html
# Found the URL: /canada/en_us.html
# Found the URL: http://www.pgatour.com/la/en.html
# Found the URL: http://www.pgatourserieschina.com/
# Found the URL: http://www.lpga.com
# Found the URL: javascript:void(0);
# Found the URL: http://www.pgatour.cn
# Found the URL: https://www.teeoff.com/?cid=pgatour%7CTopNavLink%7C%7C%7C
# Found the URL: #
# Found the URL: https://www.pgatour.com/leaderboard.html
# Found the URL: /tournaments/schedule.html
# ...

# %%
for golfer in range:
    all = soup.find_all("li", {"class":"", "data-category-index":index})
    for a in all:
        print(a['href'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9d7688c9c801> in <module>
# ----> 1 for golfer in range:
#       2     all = soup.find_all("li", {"class":"", "data-category-index":index})
#       3     for a in all:
#       4         print(a['href'])
#
# TypeError: 'type' object is not iterable

# %%
for a in soup.find_all('a', href=True):
    print ("Found the URL:", a['href'])
# Out:
# Found the URL: #
# Found the URL: http://windows.microsoft.com/en-us/internet-explorer/download-ie
# Found the URL: https://www.pgatour.com
# Found the URL: https://www.pgatour.com
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: javascript:void(0);
# Found the URL: /champions.html
# Found the URL: /korn-ferry-tour.html
# Found the URL: /canada/en_us.html
# Found the URL: http://www.pgatour.com/la/en.html
# Found the URL: http://www.pgatourserieschina.com/
# Found the URL: http://www.lpga.com
# Found the URL: javascript:void(0);
# Found the URL: http://www.pgatour.cn
# Found the URL: https://www.teeoff.com/?cid=pgatour%7CTopNavLink%7C%7C%7C
# Found the URL: #
# Found the URL: https://www.pgatour.com/leaderboard.html
# Found the URL: /tournaments/schedule.html
# ...

# %%
for index in soup.find_all("li", {"class":"", "data-category-index":index}):
    for a in soup.find_all('a', href=True):
         print ("Found the URL:", a['href'])
# Out:
# tml
# Found the URL: /stats/stat.076.html
# Found the URL: /stats/stat.02329.html
# Found the URL: /stats/stat.02331.html
# Found the URL: /stats/stat.431.html
# Found the URL: javascript:void(0)
# Found the URL: /stats/stat.02375.html
# Found the URL: /stats/stat.02374.html
# Found the URL: /stats/stat.02373.html
# Found the URL: /stats/stat.02372.html
# Found the URL: /stats/stat.02371.html
# Found the URL: /stats/stat.02370.html
# Found the URL: /stats/stat.02369.html
# Found the URL: /stats/stat.02368.html
# Found the URL: /stats/stat.02367.html
# Found the URL: /stats/stat.02366.html
# Found the URL: /stats/stat.02365.html
# Found the URL: /stats/stat.02364.html
# Found the URL: /stats/stat.02363.html
# Found the URL: /stats/stat.02362.html
# Found the URL: /stats/stat.437.html
# Found the URL: /stats/stat.432.html
# Found the URL: /stats/stat.433.html
# Found the URL: javascript:void(0)
# Found the URL: /stats/stat.02333.html
# Found the URL: /stats/stat.02334.html
# ...
