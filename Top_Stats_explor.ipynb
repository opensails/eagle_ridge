# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
data = pd.read_csv('top_stats.csv')

# %%
data.head()
# Out:
#        Row Labels  Sum of TOTAL ROUNDS  Sum of GREENS HIT_x  \
# 0  Aaron Baddeley                   33                  387
# 1      Aaron Wise                   31                  401
# 2   Abraham Ancer                   40                  483
# 3     Adam Hadwin                   31                  389
# 4       Adam Long                   54                  667
#
#    Sum of # OF BIRDIE OR BETTER  Sum of TOTAL SG:ARG  Sum of RATING  \
# 0                            29               18.905            3.2
# 1                            25               -2.253            6.8
# 2                            35                3.753            7.0
# 3                            30                4.964            5.0
# 4                            41               -0.487            5.5
#
#    Sum of PAR OR BETTER  Sum of # BUNKERS  Sum of # SAVES  \
# 0                   132                60              36
# 1                    89                43              22
# ...

# %%
data.describe()
# Out:
#        Sum of TOTAL ROUNDS  Sum of GREENS HIT_x  Sum of # OF BIRDIE OR BETTER  \
# count           232.000000           232.000000                    232.000000
# mean             66.353448           798.741379                     54.715517
# std             503.261669          6058.172062                    415.142552
# min              14.000000           145.000000                      1.000000
# 25%              26.000000           307.000000                     17.000000
# 50%              34.000000           400.500000                     26.000000
# 75%              42.000000           503.000000                     38.000000
# max            7697.000000         92654.000000                   6347.000000
#
#        Sum of TOTAL SG:ARG  Sum of RATING  Sum of PAR OR BETTER  \
# count           232.000000     225.000000            232.000000
# mean              0.546198      12.337778            235.637931
# std               7.779171      92.138850           1787.279622
# ...
